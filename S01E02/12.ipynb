# %%
from helper import haversine
Lista_elektrowni = ([
    {'name': 'Zabrze', 'latitude': 50.3141, 'longitude': 18.7858}, 
 {'name': 'Piotrkow Trybunalski', 'latitude': 51.4129, 'longitude': 19.7032}, 
 {'name': 'Grudziadz', 'latitude': 53.4841, 'longitude': 18.7537}, 
 {'name': 'Tczew', 'latitude': 54.0924, 'longitude': 18.7779},
 {'name': 'Radom', 'latitude': 51.402, 'longitude': 21.1471}, 
 {'name': 'Chelmno', 'latitude': 53.3492, 'longitude': 18.4261}, 
 {'name': 'Zarnowiec', 'latitude': 50.4844, 'longitude': 19.8631}])
# Out:
# c:\Users\wolkt\Desktop\AI_Devs4\Zadania\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
# ('Lokalizacje Wojciech Bielik:
wb = [
{'latitude': 52.592, 'longitude': 14.635},
{'latitude': 53.355, 'longitude': 18.415},
{'latitude': 52.742, 'longitude': 15.212},
{'latitude': 52.652, 'longitude': 16.825},
{'latitude': 53.142, 'longitude': 16.745},
{'latitude': 50.448, 'longitude': 8.761},
{'latitude': 53.135, 'longitude': 17.985},
{'latitude': 52.505, 'longitude': 13.445}]
# "Poziom dostępu: \n{'name': 'Wojciech', 'surname': 'Bielik', 'accessLevel': 7}"

# ('Lokalizacje Wacław Jasiński: \n'
wj = [
{'latitude': 50.198, 'longitude': 20.275},
{'latitude': 52.215, 'longitude': 21.002},
{'latitude': 53.078, 'longitude': 21.585},
{'latitude': 53.185, 'longitude': 22.042},
{'latitude': 52.602, 'longitude': 21.442},
{'latitude': 51.252, 'longitude': 22.551},
{'latitude': 53.125, 'longitude': 22.715},
{'latitude': 52.505, 'longitude': 13.445}]
# "Poziom dostępu: \n{'name': 'Wojciech', 'surname': 'Bielik', 'accessLevel': 7}"

# %%
for elektrownia in Lista_elektrowni:
    for lokalizacja in wb:
        distance = haversine(elektrownia['latitude'], elektrownia['longitude'], lokalizacja['latitude'], lokalizacja['longitude'])
        print(f"Odległość między {elektrownia['name']} wynosi {distance} km")
# Out:
# Odległość między Zabrze wynosi 383.13817595912354 km
# Odległość między Zabrze wynosi 339.08985585502774 km
# Odległość między Zabrze wynosi 365.97915290176434 km
# Odległość między Zabrze wynosi 293.2583263945676 km
# Odległość między Zabrze wynosi 344.3970238647231 km
# Odległość między Zabrze wynosi 710.4415719966801 km
# Odległość między Zabrze wynosi 318.47691475493576 km
# Odległość między Zabrze wynosi 443.17988557413383 km
# Odległość między Piotrkow Trybunalski wynosi 370.789321736121 km
# Odległość między Piotrkow Trybunalski wynosi 232.96878813570228 km
# Odległość między Piotrkow Trybunalski wynosi 340.57522932612113 km
# Odległość między Piotrkow Trybunalski wynosi 240.28541734258496 km
# Odległość między Piotrkow Trybunalski wynosi 278.2922755415664 km
# Odległość między Piotrkow Trybunalski wynosi 773.5751680157399 km
# Odległość między Piotrkow Trybunalski wynosi 224.33834601408975 km
# Odległość między Piotrkow Trybunalski wynosi 445.51818752925453 km
# ...

# %%
from haversine import haversine

wb = (53.355, 18.415)
Chelmno = (53.3492, 18.4261)

distance = haversine(wb, Chelmno)
print(f"Odległość między {wb} a {Chelmno} wynosi {distance} km")
# Out:
# Odległość między (53.355, 18.415) a (53.3492, 18.4261) wynosi 0.9791345880662097 km

# %%
Args = {'person_locations': [{'latitude': 50.662, 'longitude': 17.938}, {'latitude': 50.3015, 'longitude': 18.7912}, {'latitude': 50.2972, 'longitude': 18.661}, {'latitude': 50.2512, 'longitude': 19.0125}, {'latitude': 51.115, 'longitude': 17.062}, {'latitude': 51.776, 'longitude': 19.489}, {'latitude': 51.651, 'longitude': 17.822}], 'power_plants_list': [{'name': 'Zabrze', 'latitude': 50.27, 'longitude': 19.04, 'code': 'PWR3847PL'}, {'name': 'Piotrków Trybunalski', 'latitude': 51.73, 'longitude': 19.47, 'code': 'PWR5921PL'}, {'name': 'Grudziądz', 'latitude': 53.45, 'longitude': 18.6, 'code': 'PWR7264PL'}, {'name': 'Tczew', 'latitude': 53.9, 'longitude': 18.5, 'code': 'PWR1593PL'}, {'name': 'Radom', 'latitude': 51.4, 'longitude': 21.15, 'code': 'PWR8406PL'}, {'name': 'Chelmno', 'latitude': 53.2, 'longitude': 19.4, 'code': 'PWR2758PL'}, {'name': 'Żarnowiec', 'latitude': 53.5, 'longitude': 20.0, 'code': 'PWR6132PL'}]}

# %%
Args['power_plants_list']
# Out:
# [{'name': 'Zabrze',
#   'latitude': 50.27,
#   'longitude': 19.04,
#   'code': 'PWR3847PL'},
#  {'name': 'Piotrków Trybunalski',
#   'latitude': 51.73,
#   'longitude': 19.47,
#   'code': 'PWR5921PL'},
#  {'name': 'Grudziądz',
#   'latitude': 53.45,
#   'longitude': 18.6,
#   'code': 'PWR7264PL'},
#  {'name': 'Tczew', 'latitude': 53.9, 'longitude': 18.5, 'code': 'PWR1593PL'},
#  {'name': 'Radom', 'latitude': 51.4, 'longitude': 21.15, 'code': 'PWR8406PL'},
#  {'name': 'Chelmno', 'latitude': 53.2, 'longitude': 19.4, 'code': 'PWR2758PL'},
#  {'name': 'Żarnowiec',
#   'latitude': 53.5,
#   'longitude': 20.0,
#   'code': 'PWR6132PL'}]

# %%
from agent_version.helper import get_closest_power_plant

args = {'person_locations': [{'latitude': 50.662, 'longitude': 17.938}, {'latitude': 50.3015, 'longitude': 18.7912}, {'latitude': 50.2972, 'longitude': 18.661}, {'latitude': 50.2512, 'longitude': 19.0125}, {'latitude': 51.115, 'longitude': 17.062}, {'latitude': 51.776, 'longitude': 19.489}, {'latitude': 51.651, 'longitude': 17.822}],
'power_plants_list': [{'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, {'name': 'Piotrków Trybunalski', 'latitude': 51.413, 'longitude': 19.703, 'code': 'PWR5921PL'}, {'name': 'Grudziądz', 'latitude': 53.702, 'longitude': 17.545, 'code': 'PWR7264PL'}, {'name': 'Tczew', 'latitude': 54.345, 'longitude': 18.612, 'code': 'PWR1593PL'}, {'name': 'Radom', 'latitude': 51.252, 'longitude': 22.551, 'code': 'PWR8406PL'}, {'name': 'Chelmno', 'latitude': 53.135, 'longitude': 17.985, 'code': 'PWR2758PL'}]}

print(get_closest_power_plant(person_locations=args['person_locations'], power_plants_list=args['power_plants_list']))
# Out:
# closest_plant: {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, distance: 1.438158594094973
# {'closest_plant': {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, 'distance': 1.438158594094973}

# %%
from agent_version.helper import get_closest_power_plant

args = {'person_locations': [{'latitude': 50.662, 'longitude': 17.938}, {'latitude': 50.3015, 'longitude': 18.7912}, {'latitude': 50.2972, 'longitude': 18.661}, {'latitude': 50.2512, 'longitude': 19.0125}, {'latitude': 51.115, 'longitude': 17.062}, {'latitude': 51.776, 'longitude': 19.489}, {'latitude': 51.651, 'longitude': 17.822}],
'power_plants_list': [{'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, {'name': 'Piotrków Trybunalski', 'latitude': 51.413, 'longitude': 19.703, 'code': 'PWR5921PL'}, {'name': 'Grudziądz', 'latitude': 53.702, 'longitude': 17.545, 'code': 'PWR7264PL'}, {'name': 'Tczew', 'latitude': 54.345, 'longitude': 18.612, 'code': 'PWR1593PL'}, {'name': 'Radom', 'latitude': 51.252, 'longitude': 22.551, 'code': 'PWR8406PL'}, {'name': 'Chelmno', 'latitude': 53.135, 'longitude': 17.985, 'code': 'PWR2758PL'}]}

print(get_closest_power_plant(person_locations=args['person_locations'], power_plants_list=args['power_plants_list']))
# Out:
# closest_plant: {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, distance: 1.438158594094973
# {'closest_plant': {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, 'distance': 1.438158594094973}

# %%
Args = {'person_locations': [{'latitude': 53.702, 'longitude': 17.545}, {'latitude': 53.665, 'longitude': 15.125}, {'latitude': 53.555, 'longitude': 14.842}, {'latitude': 53.442, 'longitude': 14.535}, {'latitude': 53.972, 'longitude': 14.785}, {'latitude': 54.055, 'longitude': 15.252}, {'latitude': 54.795, 'longitude': 18.395}, {'latitude': 54.345, 'longitude': 18.612}, {'latitude': 53.715, 'longitude': 16.682}, {'latitude': 53.815, 'longitude': 14.962}, {'latitude': 54.182, 'longitude': 15.589}, {'latitude': 54.521, 'longitude': 18.515}, {'latitude': 54.032, 'longitude': 14.731}, {'latitude': 54.068, 'longitude': 14.922}, {'latitude': 53.955, 'longitude': 18.512}, {'latitude': 54.085, 'longitude': 18.92}, {'latitude': 54.205, 'longitude': 16.185}], 'power_plants_list': [{'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, {'name': 'Piotrków Trybunalski', 'latitude': 51.413, 'longitude': 19.703, 'code': 'PWR5921PL'}, {'name': 'Grudziądz', 'latitude': 53.482, 'longitude': 18.747, 'code': 'PWR7264PL'}, {'name': 'Tczew', 'latitude': 54.096, 'longitude': 18.577, 'code': 'PWR1593PL'}, {'name': 'Radom', 'latitude': 51.402, 'longitude': 21.147, 'code': 'PWR8406PL'}, {'name': 'Chelmno', 'latitude': 53.446, 'longitude': 18.746, 'code': 'PWR2758PL'}]}
print(get_closest_power_plant(**args))
# Out:
# closest_plant: {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, distance: 1.438158594094973
# {'closest_plant': {'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, 'distance': 1.438158594094973}

# %%
Args = {'person_locations': [{'latitude': 52.592, 'longitude': 14.635}, {'latitude': 53.355, 'longitude': 18.415}, {'latitude': 52.742, 'longitude': 15.212}, {'latitude': 52.652, 'longitude': 16.825}, {'latitude': 53.142, 'longitude': 16.745}, {'latitude': 50.448, 'longitude': 8.761}, {'latitude': 53.135, 'longitude': 17.985}, {'latitude': 52.505, 'longitude': 13.445}], 'power_plants_list': [{'name': 'Zabrze', 'latitude': 50.314, 'longitude': 18.786, 'code': 'PWR3847PL'}, {'name': 'Piotrków Trybunalski', 'latitude': 51.413, 'longitude': 19.703, 'code': 'PWR5921PL'}, {'name': 'Grudziądz', 'latitude': 53.482, 'longitude': 18.747, 'code': 'PWR7264PL'}, {'name': 'Tczew', 'latitude': 54.096, 'longitude': 18.577, 'code': 'PWR1593PL'}, {'name': 'Radom', 'latitude': 51.402, 'longitude': 21.147, 'code': 'PWR8406PL'}, {'name': 'Chelmno', 'latitude': 53.446, 'longitude': 18.746, 'code': 'PWR2758PL'}]}
print(get_closest_power_plant(**Args))
# Out:
# closest_plant: {'name': 'Chelmno', 'latitude': 53.446, 'longitude': 18.746, 'code': 'PWR2758PL'}, distance: 24.164703370568258
# {'closest_plant': {'name': 'Chelmno', 'latitude': 53.446, 'longitude': 18.746, 'code': 'PWR2758PL'}, 'distance': 24.164703370568258}

# %%
from agent_version.helper import get_closest_power_plant

wj = [
{'latitude': 50.198, 'longitude': 20.275},
{'latitude': 52.215, 'longitude': 21.002},
{'latitude': 53.078, 'longitude': 21.585},
{'latitude': 53.185, 'longitude': 22.042},
{'latitude': 52.602, 'longitude': 21.442},
{'latitude': 51.252, 'longitude': 22.551},
{'latitude': 53.125, 'longitude': 22.715},
{'latitude': 52.505, 'longitude': 13.445}]
chelmno = [{'latitude': 53.446, 'longitude': 18.746}]
print(get_closest_power_plant(power_plants_list=chelmno, person_locations=wj))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from agent_version.helper import get_closest_power_plant
#       3 wj = [
#       4 {'latitude': 50.198, 'longitude': 20.275},
#       5 {'latitude': 52.215, 'longitude': 21.002},
#    (...)
#      10 {'latitude': 53.125, 'longitude': 22.715},
#      11 {'latitude': 52.505, 'longitude': 13.445}]
#      12 chelmno = [{'latitude': 53.446, 'longitude': 18.746}]
#
# File c:\Users\wolkt\Desktop\AI_Devs4\Zadania\S01E02\agent_version\helper.py:6
#       4 from pathlib import Path
#       5 from dotenv import load_dotenv
# ----> 6 from haversine import haversine
#       7 import os
#       9 load_dotenv()
#
# ModuleNotFoundError: No module named 'haversine'
