# %%
import datetime
d = '1999'
p = datetime.date(int(d),1,1)
p
# Out:
# datetime.date(1999, 1, 1)

# %%
from pathlib import Path
import pandas as pd
out_path = "people_filtered.csv"
df_filtered = pd.read_csv(out_path, sep=";")

# %%
df_filtered.iloc[[1,5]]
# Out:
#    Unnamed: 0    name     surname gender   birthDate birthPlace birthCountry  \
# 1        1383  Cezary     Walczak      M  1989-10-25  Grudziądz       Polska
# 5        2131  Edward  Wiśniewski      M  1988-08-21  Grudziądz       Polska
#
#                                                  job
# 1  Wykonawca budowlany, którego zadaniem jest two...
# 5  Ta osoba tworzy fundamenty i ściany budynków, ...

# %%
import os
os.path.exists(out_path)
# Out:
# True
